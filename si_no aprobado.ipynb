# %%
print ("ingresa la calificacion: ")
cal=float(input())
if(cal>=7):
 print("aprobado")

else:
 print("no aprobado")

 #en las decisiones se tienen que pone los dos puntos (:) para que corra el programa 
 # if es si y else es no en las decisiones
