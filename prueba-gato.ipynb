# %%
print ("a11 | a12 | a13" )
print ("b11 | b12 | b13 ")
print ("c11 |")
a11=0
a12=0
a13=0
b11=0
b12=0
b13=0
c11=0
c12=0
c13=0

jugador1=input('Ingresa la casilla: ')
if(jugador1=="a11"):
  a11=1
if(jugador1=="a12"):
  a12=1
if(jugador1=="a13"):
  a13=1
if(jugador1=="b11"):
  b11=1
if(jugador1=="b12"):
  b12=1
if(jugador1=="b13"):
  b13=1
if(jugador1=="c11"):
  c11=1
if(jugador1=="c12"):
  c12=1
if(jugador1=="c13"):
  c13=1
# Out:
# Ingresa la casilla: a11
