# %%
AlumnosFavoritos=['karina', 'carlos', 'edith', 'hiram', 'manolo', 'dany', 'azucena']
print(AlumnosFavoritos[4])
# Out:
# manolo

# %%
Calificaciones=['8', '10', '9', '5', '7', '4', '1']
print(Calificaciones[4])
# Out:
# 7

# %%
Prueba=[]
Prueba.append(int(input('ingresa un numero: ')))
Prueba.append(int(input('ingresa un numero: ')))
Prueba.append(int(input('ingresa un numero: ')))
Prueba.append(int(input('ingresa un numero: ')))

print(Prueba[0])
print(Prueba[3])

Prueba[0]='texto'
# Out:
# ingresa un numero: 10
# ingresa un numero: 54
# ingresa un numero: 20
# ingresa un numero: 29
# 10
# 29

# %%
Numeros=[]
for i in range (0,5):
 Numeros.append(int(input('ingrese el numero: ')))

print(Numeros[0])
print(Numeros[3])
# Out:
# ingrese el numero: 15
# ingrese el numero: 24
# ingrese el numero: 24
# ingrese el numero: 39
# ingrese el numero: 09
# 15
# 39
