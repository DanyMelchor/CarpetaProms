# %%
D=[[1, 2, 4, 3],[8, 4, 6, 2]]
print(D[0][2])
print(D[0])
print(D[1])
# Out:
# 4
# [1, 2, 4, 3]
# [8, 4, 6, 2]

# %%
D=[[],[]]

for i in range (0,5):
  D[0].append(input("ingrese el nombre de la serie de netflix: "))
  for j in range (0,1):
     D[1].append(input("ingrese el nombre de la serie de disney: "))

print("LA SERIES DE NETFLIX: ", D[0])
print("LA SERIE DE DISNEY: ", D[1])
# Out:
# ingrese el nombre de la serie de netflix: A
# ingrese el nombre de la serie de disney: B
# ingrese el nombre de la serie de netflix: A
# ingrese el nombre de la serie de disney: B
# ingrese el nombre de la serie de netflix: A
# ingrese el nombre de la serie de disney: B
# ingrese el nombre de la serie de netflix: A
# ingrese el nombre de la serie de disney: B
# ingrese el nombre de la serie de netflix: A
# ingrese el nombre de la serie de disney: B
# LA SERIES DE NETFLIX:  ['A', 'A', 'A', 'A', 'A']
# LA SERIE DE DISNEY:  ['B', 'B', 'B', 'B', 'B']
