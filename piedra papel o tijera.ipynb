# %%
#1:piedra
#2:papel
#3:tijera

#se puede colocar como ultima opcion el "elif"

print ("ingresa la primera opcion:")
op1=int(input())
print ("ingrese la segunda opcion: ")
op2=int(input())

if(op1==1 and op2==2):
 print ("gana jugador 2")

else:
   if(op1==1 and op2==3):
    print ("gana el jugador 1")

   else:
      if(op1==1 and op==1):
        print ("empate")

      else:
        if(op1==2 and op2==2):
         print ("empate")

        else:
          if(op1==2 and op2==3):
           print ("Gana jugador 2")

          else:
            if(op1==2 and op2==1):
             print ("gana jugador 1")

            else:
              if(op1==3 and op2==2):
               print ("gana jugador 1")

              else:
                if(op1==3 and op2==3):
                 print ("empate")

                else:
                  if(op1==3 and op2==1):
                   print ("gana jugador 2")

                  else:
                    print ("los valores no son correctos")
# Out:
# ingresa la primera opcion:
# 2
# ingrese la segunda opcion:
# 4
# los valores no son correctos
