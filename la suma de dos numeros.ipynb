# %%
n1=int(input("ingresa el primer numero: "))
n2=int(input("ingresa el segundo numero: "))
sum=n1-n2
print ("la suma de los dos numeros es: ")
print (sum)

#tambien se puede inprimir el resultado 
#print ("el resulta de la suma de los dos numeros es:",sum)
# Out:
# ingresa el primer numero: 10
# ingresa el segundo numero: 10
# la suma de los dos numeros es:
# 0
